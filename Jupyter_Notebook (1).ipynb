# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Moses Mutua**
#
# Data Scientist in Telco

# %% [markdown]
# *I am interested in data science because it predicts customer intentions thereby making it easy for business to take right action on time. Data Science also helps make use of existing data assets optimally thereby providing value to business stakeholders*

# %% [markdown]
# ### My below code is finding the sum of 7 and 15

# %%
7 + 15
# Out:
# 22

# %% [markdown]
# The following are some famous oceans in the world
# - Indian Ocean
# - Pacific Ocean
# - Atlantic Ocean
#
# The following are some popular football clubs in Europe
# 1. Italy
#     - AC Milan
#     - Inter Milan
#
# 2. Spain
#     - Real Madrid
#     - Bercelona
#     - Osasuna
#
# 3. France
#     - Monaco
#     - PSG
#
#
# And that is well done.
# ![image.png](attachment:bb35f497-c05a-4bbf-86ef-f813abcfacf6.png)![image.png](attachment:deb089e6-0095-422b-8b9b-a2ff7692eb4b.png)
